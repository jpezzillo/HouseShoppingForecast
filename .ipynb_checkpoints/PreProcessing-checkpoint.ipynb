# %%
import pandas as pd
from neuralprophet import NeuralProphet

# %%
df = pd.read_csv("ZHVA_SingleFamilyHomes.csv",delimiter=',',header=0)
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County         NaN  ...
# 1          Chicago-Naperville-Elgin      Cook County    328512.0  ...
# 2       New York-Newark-Jersey City  New York County         NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    200347.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    506494.0  ...
#
#    2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  2020-07-31  \
# 0   1265788.0   1267571.0   1263693.0   1258883.0   1251652.0   1250914.0
# 1    875899.0    877639.0    878474.0    878589.0    878360.0    879763.0
# 2   1559391.0   1555914.0   1549257.0   1543394.0   1544410.0   1543587.0
# 3    335315.0    335773.0    336917.0    338026.0    338904.0    339605.0
# 4   1112467.0   1114185.0   1115265.0   1114898.0   1115760.0   1117977.0
#
#    2020-08-31  2020-09-30  2020-10-31  2020-11-30
# 0   1253461.0   1263221.0   1271132.0   1279123.0
# 1    881837.0    886104.0    890618.0    894135.0
# 2   1544489.0   1546494.0   1555193.0   1565909.0
# 3    340918.0    342275.0    344447.0    347078.0
# 4   1120304.0   1125059.0   1130024.0   1134341.0
#
# [5 rows x 308 columns]

# %%
zillowClean = df.filter(regex="(1997|1998|1999|2000|2001|2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020|2021|Metro|RegionName)", axis=1)

# %%
zillowDropSome = zillowClean.dropna(how='any',axis=0, thresh=252) # requiring 252 records as this is 90% of records

# %%
zillowGrilledCheese = zillowDropSome.drop("Metro",axis=1)
zillowGrilledCheese = pd.melt(zillowGrilledCheese,id_vars=["RegionName"],var_name='ds',value_name='y')
zillowGrilledCheese.head()
# Out:
#    RegionName          ds         y
# 0       60657  1997-01-31  339239.0
# 1       77494  1997-01-31  201558.0
# 2       60614  1997-01-31  524822.0
# 3       77449  1997-01-31   97868.0
# 4       77084  1997-01-31   98117.0

# %%
def forecast(x):
    x = zillowGrilledCheese[zillowGrilledCheese["RegionName"] == x]
    m = NeuralProphet()
    m.fit(x, freq="M")
    future = m.make_future_dataframe(periods=36, freq='M')
    forecast = m.predict(future)
    return forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]

# %%
forecast
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/jessepezzillo/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1675: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2b2f0d033a2b> in <module>
# ----> 1 forecast(2806)
#
# <ipython-input-12-71987ad356a7> in forecast(x)
#       2     x = zillowGrilledCheese[zillowGrilledCheese["RegionName"] == x]
#       3     m = NeuralProphet()
# ----> 4     m.fit(x, freq="M")
#       5     future = m.make_future_dataframe(periods=36, freq='M')
#       6     forecast = m.predict(future)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neuralprophet/forecaster.py in fit(self, df, freq, epochs, validate_each_epoch, valid_p, use_tqdm, plot_live_loss)
#     780             metrics_df = self._train(df_train, df_val, use_tqdm=use_tqdm, plot_live_loss=plot_live_loss)
#     781         else:
# --> 782             metrics_df = self._train(df, use_tqdm=use_tqdm, plot_live_loss=plot_live_loss)
#     783         if epochs is not None:
#     784             self.config_train.epochs = default_epochs
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neuralprophet/forecaster.py in _train(self, df, df_val, use_tqdm, plot_live_loss)
#     593                 )
#     594
# --> 595         loader = self._init_train_loader(df)
#     596         val = df_val is not None
#     597         ## Metrics
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neuralprophet/forecaster.py in _init_train_loader(self, df)
#     426                 events_config=self.events_config,
#     427             )
# --> 428         df = df_utils.normalize(df, self.data_params)
#     429         if not self.fitted:
#     430             if self.config_trend.changepoints is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neuralprophet/df_utils.py in normalize(df, data_params)
#     126     for name in df.columns:
#     127         if name not in data_params.keys():
# --> 128             raise ValueError("Unexpected column {} in data".format(name))
#     129         new_name = name
#     130         if name == "ds":
#
# ValueError: Unexpected column RegionName in data
